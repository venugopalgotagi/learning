# %% [markdown]
# <a href="https://www.kaggle.com/code/venugopalgotagi/linear-regression?scriptVersionId=278210618" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Linear Regression using Boston Housing Data

# %%
# Import statements
import logging
import numpy as np
import pandas as pd
import warnings

import seaborn as sns
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

warnings.filterwarnings("ignore")
logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler("/kaggle/working/notebook_log.log"),
            logging.StreamHandler() # Also print to console output
        ]
    )

# %%
boston_df = pd.read_csv("/kaggle/input/bostonhousingdataset/boston-housing-dataset.csv")
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    int64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    int64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  B           506 non-null    float64
#  13  LSTAT       506 non-null    float64
#  14  MEDV        506 non-null    float64
# dtypes: float64(12), int64(3)
# memory usage: 59.4 KB

# %%
# Delete None values  and index column

boston_df.isna().sum()

#remove None and  values and first column (index column)
boston_df = boston_df.dropna()

boston_df = boston_df.drop(columns=['Unnamed: 0'],errors='ignore')

boston_df.dtypes
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# Get correlation coeeficients
crr_boston = boston_df.corr().round(2)
# Print heat map
plt.figure(figsize=(13,13))
sns.heatmap(data = crr_boston, vmin=-1,vmax=1,center=0, annot=True, cmap='vlag')
plt.show()

# %%
#Show coefficients that are greater than 0.5
abs(crr_boston.MEDV) >= 0.47
logging.info(boston_df.corr().abs().nlargest(4, 'MEDV').index)
# Out:
# 2025-11-15 08:17:18,043 - INFO - Index(['MEDV', 'LSTAT', 'RM', 'PTRATIO'], dtype='object')

# %%
#print the correlation of columns
plt.scatter(x=boston_df['LSTAT'],y=boston_df['RM'], c='RED')
plt.xlabel('LSTAT')
plt.ylabel('RM')
plt.show()
#print the correlation of columns
plt.scatter(x=boston_df['RM'],y=boston_df['MEDV'],marker='X',c='GREEN')
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.show()

plt.scatter(x=boston_df['LSTAT'],y=boston_df['MEDV'],marker='o',c='ORANGE')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.show()

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(boston_df['LSTAT'],boston_df['RM'],boston_df['MEDV'],c='GREEN')
plt.show()

# %%
X = boston_df.copy()
logging.info(X.head())
logging.info("="*100)
y = pd.DataFrame(np.c_[boston_df['MEDV']],columns=['MEDV'])
logging.info(y.head())
# Out:
# 2025-11-15 08:17:18,697 - INFO -       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# 2025-11-15 08:17:18,709 - INFO - ====================================================================================================
# 2025-11-15 08:17:18,710 - INFO -    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5,shuffle=True)
X_cv,tmp_test,y_cv,tmp_y = train_test_split(X_test,y_test,test_size=0.2,random_state=5,shuffle=True)
logging.info(f"{X_train.shape}, {y_train.shape}")
logging.info(f"{X_test.shape},{y_test.shape}")
logging.info(f"{X_cv.shape},{y_cv.shape}")
# Out:
# 2025-11-15 08:17:18,745 - INFO - (404, 14), (404, 1)
# 2025-11-15 08:17:18,746 - INFO - (102, 14),(102, 1)
# 2025-11-15 08:17:18,747 - INFO - (81, 14),(81, 1)

# %%
scalar = StandardScaler()
pca = PCA(n_components=13)
poly = PolynomialFeatures(degree=2,include_bias=False)

X_train = scalar.fit_transform(X_train)
X_train = pca.fit_transform(X_train)
X_train= poly.fit_transform(X_train)

X_cv = scalar.transform(X_cv)
X_cv = pca.transform(X_cv)
X_cv = poly.transform(X_cv)

# %%
linear_regression = LinearRegression()
linear_regression.fit(X_train,y_train)

logging.info(linear_regression.coef_)
logging.info(linear_regression.intercept_)
# Out:
# 2025-11-15 08:17:18,846 - INFO - [[-2.64948597e+00 -1.12265997e+01  8.74578488e+00 -2.85561980e+01
#    1.63084204e+01  7.46812582e+00 -7.43291301e+00  3.31701605e+00
#    3.78735722e+00  4.74495104e+00  3.26710756e+00  2.03443604e+00
#    6.45308228e+00  8.68039792e-02  8.18672162e-02 -5.08225225e-02
#    1.40046831e-02 -7.27762971e-02  2.57911466e-02  3.69323962e-01
#    2.29377013e-01 -6.01763970e-02 -1.02113685e-01 -1.58791826e-02
#    1.35807307e-01  7.82839492e-02  1.91377813e+00 -2.00306304e+00
#    6.47995318e+00 -4.22522896e+00 -1.74014303e+00  1.58609496e+00
#   -4.05119439e-01 -2.19595583e-02 -4.94080768e-01  9.50891509e-03
#   -1.70004930e-01 -4.89394169e-01  2.98730027e-01 -3.73134296e+00
#    2.28440263e+00  5.84999288e-01 -1.11544038e+00  2.86226807e-01
#    1.84587316e-02 -7.96303096e-02  3.93328213e-02  2.24994933e-01
#    2.92514225e-01  5.39564778e+00 -7.15316837e+00 -3.28024780e+00
#    2.27463534e+00 -7.96146705e-01  2.98298605e-02 -1.01432126e+00
#    6.10598353e-02 -2.78426792e-01 -8.28564773e-01  2.31991072e+00
#    1.95104382e+00 -1.84020497e+00  4.08048265e-01  6.89940818e-02
#    5.15699573e-01 -2.19926654e-02  1.39723692e-01  5.07217972e-01
#    2.73151626e-01 -8.44893707e-01  3.21782198e-01  7.71011239e-02
#   -1.33382983e-01  3.05389696e-02  1.89474746e-01  2.76202099e-01
#    6.10093061e-01  2.86958621e-01 -3.15093182e-02 -6.02712616e-01
#    2.49971584e-02  2.45644023e-01 -2.97819683e-02  1.58415126e-01
#   -5.44740265e-02 -4.57818100e-02 -5.04372361e-02  1.64249569e-01
#    1.38073083e-01 -3.75213630e-02  6.84617298e-02  6.42437175e-03
#   -1.16937461e-02 -2.60215645e-02 -1.58493663e-02  7.04392314e-02
#    4.32979693e-02  4.96353992e-02  3.73764074e-03 -2.69459446e-02
#    5.36351866e-02  5.40810591e-02  7.11220306e-02  5.43972996e-02]]
# 2025-11-15 08:17:18,849 - INFO - [11.28242848]

# %%
y_train_pred = linear_regression.predict(X_train)
logging.info(f"{linear_regression.score(X_train,y_train):.2f}")
logging.info(f"{mean_squared_error(y_train,y_train_pred):.2f}")
plt.scatter(x=y_train, y=y_train_pred,c='GREEN',marker='X')
plt.show()
# Out:
# 2025-11-15 08:17:18,912 - INFO - 1.00
# 2025-11-15 08:17:18,915 - INFO - 0.00

# %%
y_cv_pred = linear_regression.predict(X_cv)
logging.info(f"{linear_regression.score(X_cv,y_cv):.2f}")
logging.info(f"{mean_squared_error(y_cv,y_cv_pred):.2f}")
plt.scatter(x=y_train, y=y_train_pred,c='GREEN',marker='X')
plt.show()
# Out:
# 2025-11-15 08:17:19,084 - INFO - 1.00
# 2025-11-15 08:17:19,087 - INFO - 0.00

# %%
X_test = scalar.transform(X_test)
X_test = pca.transform(X_test)
X_test = poly.transform(X_test)

y_test_pred = linear_regression.predict(X_test)
logging.info(f"{linear_regression.score(X_test,y_test):.2f}")
logging.info(f"{mean_squared_error(y_test,y_test_pred):.2f}")
plt.scatter(x=y_test, y=y_test_pred,c='GREEN',marker='X')
plt.show()
# Out:
# 2025-11-15 08:17:19,240 - INFO - 1.00
# 2025-11-15 08:17:19,242 - INFO - 0.00
